# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from datetime import datetime
import glob
import seaborn as sns

# %%
files = [i for i in glob.glob('data/*.{}'.format('csv'))]
sorted(files)
# Out:
# ['data\\CAvideos.csv',
#  'data\\DEvideos.csv',
#  'data\\FRvideos.csv',
#  'data\\GBvideos.csv',
#  'data\\INvideos.csv',
#  'data\\USvideos.csv']

# %%
dfs = list()
for file in files:
    print(file)
    country = ''.join([c for c in file if c.isupper()])
    df = pd.read_csv(file)
    df['country'] = country
    dfs.append(df)
    
df = pd.concat(dfs)
# Out:
# data\CAvideos.csv
# data\DEvideos.csv
# data\FRvideos.csv
# data\GBvideos.csv
# data\INvideos.csv
# data\USvideos.csv

# %%
df
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# 5      0yIWz1XEeyc      17.14.11
# 6      _uM5kFfkhB8      17.14.11
# 7      2kyS6SvSYSE      17.14.11
# 8      JzCsM1vtn78      17.14.11
# 9      43sm-QwLcx4      17.14.11
# 10     H1KBHFXm2Bg      17.14.11
# 11     U3xLOo-CNwo      17.14.11
# 12     FyZMnhUtLfE      17.14.11
# 13     7MxiQ4v0EnE      17.14.11
# 14     LUzsOyWp9lw      17.14.11
# 15     AS9-ITLhQxo      17.14.11
# 16     gifPYwArCVQ      17.14.11
# 17     8NHA23f7LvU      17.14.11
# 18     fy-CuCzaPp8      17.14.11
# 19     kzwfHumJyYc      17.14.11
# 20     nc99ccSXST0      17.14.11
# 21     puqaWrEC7tY      17.14.11
# 22     6H3wVsceoS0      17.14.11
# 23     PRlmRnU9qts      17.14.11
# 24     ZhhXLMbZ1rQ      17.14.11
# 25     wuf2KinLxZ8      17.14.11
# 26     aVTAU_4i9AY      17.14.11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239662 entries, 0 to 40948
# Data columns (total 17 columns):
# video_id                  239662 non-null object
# trending_date             239662 non-null object
# title                     239662 non-null object
# channel_title             239662 non-null object
# category_id               239662 non-null int64
# publish_time              239662 non-null object
# tags                      239662 non-null object
# views                     239662 non-null int64
# likes                     239662 non-null int64
# dislikes                  239662 non-null int64
# comment_count             239662 non-null int64
# thumbnail_link            239662 non-null object
# comments_disabled         239662 non-null bool
# ratings_disabled          239662 non-null bool
# video_error_or_removed    239662 non-null bool
# description               232159 non-null object
# country                   239662 non-null object
# ...

# %%
df = df.dropna(how='any',inplace=False, axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 232159 entries, 0 to 40948
# Data columns (total 17 columns):
# video_id                  232159 non-null object
# trending_date             232159 non-null object
# title                     232159 non-null object
# channel_title             232159 non-null object
# category_id               232159 non-null int64
# publish_time              232159 non-null object
# tags                      232159 non-null object
# views                     232159 non-null int64
# likes                     232159 non-null int64
# dislikes                  232159 non-null int64
# comment_count             232159 non-null int64
# thumbnail_link            232159 non-null object
# comments_disabled         232159 non-null bool
# ratings_disabled          232159 non-null bool
# video_error_or_removed    232159 non-null bool
# description               232159 non-null object
# country                   232159 non-null object
# ...

# %%
df = df.drop_duplicates(keep="last")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227716 entries, 0 to 40948
# Data columns (total 17 columns):
# video_id                  227716 non-null object
# trending_date             227716 non-null object
# title                     227716 non-null object
# channel_title             227716 non-null object
# category_id               227716 non-null int64
# publish_time              227716 non-null object
# tags                      227716 non-null object
# views                     227716 non-null int64
# likes                     227716 non-null int64
# dislikes                  227716 non-null int64
# comment_count             227716 non-null int64
# thumbnail_link            227716 non-null object
# comments_disabled         227716 non-null bool
# ratings_disabled          227716 non-null bool
# video_error_or_removed    227716 non-null bool
# description               227716 non-null object
# country                   227716 non-null object
# ...

# %%
category_id = {}

with open('data/US_category_id.json', 'r') as f:
    data = json.load(f)
    for category in data['items']:
        category_id[category['id']] = category['snippet']['title']
df['category_id']=df['category_id'].astype(str).map(category_id) 
print(df['category_id'].unique())
# Out:
# ['Music' 'Comedy' 'Entertainment' 'News & Politics' 'People & Blogs'
#  'Howto & Style' 'Film & Animation' 'Science & Technology' 'Gaming'
#  'Sports' 'Nonprofits & Activism' 'Pets & Animals' 'Travel & Events'
#  'Autos & Vehicles' 'Education' 'Shows' 'Movies' 'Trailers']

# %%
category_id
# Out:
# {'1': 'Film & Animation',
#  '2': 'Autos & Vehicles',
#  '10': 'Music',
#  '15': 'Pets & Animals',
#  '17': 'Sports',
#  '18': 'Short Movies',
#  '19': 'Travel & Events',
#  '20': 'Gaming',
#  '21': 'Videoblogging',
#  '22': 'People & Blogs',
#  '23': 'Comedy',
#  '24': 'Entertainment',
#  '25': 'News & Politics',
#  '26': 'Howto & Style',
#  '27': 'Education',
#  '28': 'Science & Technology',
#  '29': 'Nonprofits & Activism',
#  '30': 'Movies',
#  '31': 'Anime/Animation',
#  '32': 'Action/Adventure',
#  '33': 'Classics',
#  '34': 'Comedy',
#  '35': 'Documentary',
#  '36': 'Drama',
#  '37': 'Family',
#  '38': 'Foreign',
#  '39': 'Horror',
#  '40': 'Sci-Fi/Fantasy',
#  '41': 'Thriller',
#  '42': 'Shorts',
#  '43': 'Shows',
#  '44': 'Trailers'}

# %%
df['category_id'].unique()
# Out:
# array(['Music', 'Comedy', 'Entertainment', 'News & Politics',
#        'People & Blogs', 'Howto & Style', 'Film & Animation',
#        'Science & Technology', 'Gaming', 'Sports',
#        'Nonprofits & Activism', 'Pets & Animals', 'Travel & Events',
#        'Autos & Vehicles', 'Education', 'Shows', 'Movies', 'Trailers'],
#       dtype=object)

# %%
df
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# 5      0yIWz1XEeyc      17.14.11
# 6      _uM5kFfkhB8      17.14.11
# 7      2kyS6SvSYSE      17.14.11
# 8      JzCsM1vtn78      17.14.11
# 9      43sm-QwLcx4      17.14.11
# 10     H1KBHFXm2Bg      17.14.11
# 11     U3xLOo-CNwo      17.14.11
# 12     FyZMnhUtLfE      17.14.11
# 13     7MxiQ4v0EnE      17.14.11
# 14     LUzsOyWp9lw      17.14.11
# 15     AS9-ITLhQxo      17.14.11
# 16     gifPYwArCVQ      17.14.11
# 17     8NHA23f7LvU      17.14.11
# 18     fy-CuCzaPp8      17.14.11
# 19     kzwfHumJyYc      17.14.11
# 20     nc99ccSXST0      17.14.11
# 21     puqaWrEC7tY      17.14.11
# 22     6H3wVsceoS0      17.14.11
# 23     PRlmRnU9qts      17.14.11
# 24     ZhhXLMbZ1rQ      17.14.11
# 25     wuf2KinLxZ8      17.14.11
# 26     aVTAU_4i9AY      17.14.11
# ...

# %%
 ax = sns.countplot(y="category_id", data=df)

# %%
plt.figure(figsize=(16,9))
ax = sns.countplot(y="category_id", hue="country", data=df)

# %%
df_likes = df[df['country']=='DE']['category_id'].value_counts().reset_index()
plt.figure(figsize=(14,9))
ax = sns.barplot(y=df_likes['index'],x=df_likes['category_id'], data=df_likes,orient='h')
plt.xlabel("Quantidade de Vídeos") 
plt.ylabel("Categorias")
# Out:
# Text(0, 0.5, 'Categorias')

# %%
labels = df.groupby(['country']).count().index
sizes = df.groupby(['country']).count()['title']

fig, ax = plt.subplots(figsize=(10,10))
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True)
ax.axis('equal')
# Out:
# (-1.111114830220697,
#  1.100529277629557,
#  -1.1018124601201256,
#  1.1100542477820001)

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#      category_id              publish_time  \
# 0          Music  2017-11-10T17:00:03.000Z
# 1         Comedy  2017-11-13T17:00:00.000Z
# 2         Comedy  2017-11-12T19:05:24.000Z
# 3  Entertainment  2017-11-12T18:01:41.000Z
# 4          Music  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df.comments_disabled.replace({True:1,False:0},inplace=True)
df.ratings_disabled.replace({True:1,False:0},inplace=True)
df.video_error_or_removed.replace({True:1,False:0},inplace=True)

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df[df['country']=='US'].corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
cat_df_gb = df[df['country']=='US']['category_id'].value_counts().reset_index()
plt.figure(figsize=(15,10))
ax = sns.barplot(y=cat_df_gb['index'],x=cat_df_gb['category_id'], data=cat_df_gb,orient='h')
plt.xlabel("Number of Videos")## From United Kingdom users : 
plt.ylabel("Categories")
plt.title("Catogories of trend videos in United Kingdom")
# Out:
# Text(0.5, 1.0, 'Catogories of trend videos in United Kingdom')

# %% [markdown]
# ### Análise de sentimento

# %%
from wordcloud import WordCloud
import nltk
#nltk.download()
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

from collections import Counter
from nltk.tokenize import RegexpTokenizer
import re

# %%
en_stopwords = list(stopwords.words('english'))
de_stopwords = list(stopwords.words('german'))   
fr_stopwords = list(stopwords.words('french'))   
en_stopwords.extend(de_stopwords)
en_stopwords.extend(fr_stopwords)

# %%
df_description_music = df[df['category_id']=='Comedy']['description']

# %%
df_description_music
filtered_sentence = [w for w in df_description_music if not w in en_stopwords]

# %%
word_dist = nltk.FreqDist(df_description_music)
hnhk = pd.DataFrame(word_dist.most_common(1000),
                    columns=['Word', 'Frequency'])

# %%
polarities = list()
compound = .0
for word in hnhk['Word'].head(1000):
    compound += SentimentIntensityAnalyzer().polarity_scores(word)['compound']

polarities.append(compound)

# %%
polarities
# Out:
# [399.69010000000003]

# %%
MAX_N = 1000
polarities = list()
category_list = df['category_id']
for cate in category_list:
    tags_word = df[df['category_id']==cate]['tags'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
    tags_word = re.sub('[^A-Za-z]+', ' ', tags_word)
    word_tokens = word_tokenize(tags_word)
    filtered_sentence = [w for w in word_tokens if not w in en_stopwords]
    without_single_chr = [word for word in filtered_sentence if len(word) > 2]

# Remove numbers
    cleaned_data_title = [word for word in without_single_chr if not word.isdigit()]      
    
# Calculate frequency distribution
    word_dist = nltk.FreqDist(cleaned_data_title)
    hnhk = pd.DataFrame(word_dist.most_common(MAX_N),
                    columns=['Word', 'Frequency'])

    compound = .0
    for word in hnhk['Word'].head(MAX_N):
        compound += SentimentIntensityAnalyzer().polarity_scores(word)['compound']

    polarities.append(compound)

category_list = pd.DataFrame(category_list)
polarities = pd.DataFrame(polarities)
tags_sentiment = pd.concat([category_list,polarities],axis=1)
tags_sentiment.columns = ['category','polarity']
tags_sentiment=tags_sentiment.sort_values('polarity').reset_index()

plt.figure(figsize=(16,10))
sns.set(style="white",context="talk")
ax = sns.barplot(x=tags_sentiment['polarity'],y=tags_sentiment['category'], data=tags_sentiment,orient='h',palette="RdBu")
plt.xlabel("Categories")
plt.ylabel("polarity")
plt.title("Polarity of Categories in Youtube videos")
